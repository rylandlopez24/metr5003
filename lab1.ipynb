# %%
import sys
print(sys.executable)
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt #e
# Out:
# /opt/anaconda3/envs/metr5003/bin/python
# Matplotlib is building the font cache; this may take a moment.
